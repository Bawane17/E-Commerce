# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data.csv", encoding = "ISO-8859-1")
df.head()

# ISO-8859-1, also known as Latin-1, is another popular encoding format for text data.
# It supports most Western European languages and is compatible with ASCII.
# To specify ISO-8859-1 encoding in Pandas, use the encoding='iso-8859-1' parameter.
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#Total number of rows and column
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# Rows = 541909,
# Columns = 8

# %%
#last top 5 rows
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
# Displaying columns names from dataset
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#Renaming columns name

d = {
    'InvoiceNo' : 'Invoice_No',
    'StockCode' : 'Stock_Code',
    'Description' : 'Description',
    'Quantity' : 'Quantity',
    'InvoiceDate' : 'Invoice_Date',
    'UnitPrice' : 'Unit_Price',
    'CustomerID' : 'Customer_ID',
    'Country' : 'Country'
}
d
# Out:
# {'InvoiceNo': 'Invoice_No',
#  'StockCode': 'Stock_Code',
#  'Description': 'Description',
#  'Quantity': 'Quantity',
#  'InvoiceDate': 'Invoice_Date',
#  'UnitPrice': 'Unit_Price',
#  'CustomerID': 'Customer_ID',
#  'Country': 'Country'}

# %%
df.rename(columns = d, inplace = True)

# %%
#Checking columns name after changing

for columns in df.columns:
    print(columns)
# Out:
# Invoice_No
# Stock_Code
# Description
# Quantity
# Invoice_Date
# Unit_Price
# Customer_ID
# Country

# %%
#Total number of columns

len(df.columns)
# Out:
# 8

# %%
#Checking data with head() method

df.head()
# Out:
#   Invoice_No Stock_Code                          Description  Quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      Invoice_Date  Unit_Price  Customer_ID         Country
# 0  12/1/2010 8:26        2.55      17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39      17850.0  United Kingdom
# 2  12/1/2010 8:26        2.75      17850.0  United Kingdom
# 3  12/1/2010 8:26        3.39      17850.0  United Kingdom
# 4  12/1/2010 8:26        3.39      17850.0  United Kingdom

# %% [markdown]
# # Data Cleaning

# %%
#DataFrame information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Invoice_No    541909 non-null  object
#  1   Stock_Code    541909 non-null  object
#  2   Description   540455 non-null  object
#  3   Quantity      541909 non-null  int64
#  4   Invoice_Date  541909 non-null  object
#  5   Unit_Price    541909 non-null  float64
#  6   Customer_ID   406829 non-null  float64
#  7   Country       541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
#Checking Columns types

df.dtypes
# Out:
# Invoice_No       object
# Stock_Code       object
# Description      object
# Quantity          int64
# Invoice_Date     object
# Unit_Price      float64
# Customer_ID     float64
# Country          object
# dtype: object

# %%
#Converting data type of "Invoice_Date" column into datetime data type

df["Invoice_Date"] = pd.to_datetime(df.Invoice_Date, format = "%m/%d/%Y %H:%M")

# %%
# Cheking data type of "Invoice_Date" column

df.dtypes
# Out:
# Invoice_No              object
# Stock_Code              object
# Description             object
# Quantity                 int64
# Invoice_Date    datetime64[ns]
# Unit_Price             float64
# Customer_ID            float64
# Country                 object
# dtype: object

# %% [markdown]
# Data type of "Invoice_Date" column data, successfully converted.

# %%
df.head()
# Out:
#   Invoice_No Stock_Code                          Description  Quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          Invoice_Date  Unit_Price  Customer_ID         Country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %%
#Decription column having data in capital type let's check

df["Description"]
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
#Calling title() method to change capital format to easy readable format

df["Description"] = df.Description.str.title()
df.head()
# Out:
#   Invoice_No Stock_Code                          Description  Quantity  \
# 0     536365     85123A   White Hanging Heart T-Light Holder         6
# 1     536365      71053                  White Metal Lantern         6
# 2     536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3     536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4     536365     84029E       Red Woolly Hottie White Heart.         6
#
#          Invoice_Date  Unit_Price  Customer_ID         Country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %%
#Checking missing values in each columns

df.isnull()
# Out:
#         Invoice_No  Stock_Code  Description  Quantity  Invoice_Date  \
# 0            False       False        False     False         False
# 1            False       False        False     False         False
# 2            False       False        False     False         False
# 3            False       False        False     False         False
# 4            False       False        False     False         False
# ...            ...         ...          ...       ...           ...
# 541904       False       False        False     False         False
# 541905       False       False        False     False         False
# 541906       False       False        False     False         False
# 541907       False       False        False     False         False
# 541908       False       False        False     False         False
#
#         Unit_Price  Customer_ID  Country
# 0            False        False    False
# 1            False        False    False
# ...

# %%
#Checking missing count of each columns

df.isna().sum()
# Out:
# Invoice_No           0
# Stock_Code           0
# Description       1454
# Quantity             0
# Invoice_Date         0
# Unit_Price           0
# Customer_ID     135080
# Country              0
# dtype: int64

# %%
#With sorting method checking missing values count on each column

df.isnull().sum().sort_values(ascending = False)
# Out:
# Customer_ID     135080
# Description       1454
# Invoice_No           0
# Stock_Code           0
# Quantity             0
# Invoice_Date         0
# Unit_Price           0
# Country              0
# dtype: int64

# %%
[null_values for null_values in df.columns if df[null_values].isna().sum() > 0]
# Out:
# ['Description', 'Customer_ID']

# %%
df.dropna(inplace = True)
df
# Out:
#        Invoice_No Stock_Code                          Description  Quantity  \
# 0          536365     85123A   White Hanging Heart T-Light Holder         6
# 1          536365      71053                  White Metal Lantern         6
# 2          536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3          536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4          536365     84029E       Red Woolly Hottie White Heart.         6
# ...           ...        ...                                  ...       ...
# 541904     581587      22613          Pack Of 20 Spaceboy Napkins        12
# 541905     581587      22899         Children'S Apron Dolly Girl          6
# 541906     581587      23254        Childrens Cutlery Dolly Girl          4
# 541907     581587      23255      Childrens Cutlery Circus Parade         4
# 541908     581587      22138        Baking Set 9 Piece Retrospot          3
#
# ...

# %%
df.isnull().sum()
# Out:
# Invoice_No      0
# Stock_Code      0
# Description     0
# Quantity        0
# Invoice_Date    0
# Unit_Price      0
# Customer_ID     0
# Country         0
# dtype: int64

# %%
df.shape
# Out:
# (406829, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Invoice_No    406829 non-null  object
#  1   Stock_Code    406829 non-null  object
#  2   Description   406829 non-null  object
#  3   Quantity      406829 non-null  int64
#  4   Invoice_Date  406829 non-null  datetime64[ns]
#  5   Unit_Price    406829 non-null  float64
#  6   Customer_ID   406829 non-null  float64
#  7   Country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
df.dtypes
# Out:
# Invoice_No              object
# Stock_Code              object
# Description             object
# Quantity                 int64
# Invoice_Date    datetime64[ns]
# Unit_Price             float64
# Customer_ID            float64
# Country                 object
# dtype: object

# %%
#Converting float data type of "Customer_ID" coulmn into integer data type

df["Customer_ID"] = df["Customer_ID"].astype("int64")

# %%
df.dtypes
# Out:
# Invoice_No              object
# Stock_Code              object
# Description             object
# Quantity                 int64
# Invoice_Date    datetime64[ns]
# Unit_Price             float64
# Customer_ID              int64
# Country                 object
# dtype: object

# %%
df.head()
# Out:
#   Invoice_No Stock_Code                          Description  Quantity  \
# 0     536365     85123A   White Hanging Heart T-Light Holder         6
# 1     536365      71053                  White Metal Lantern         6
# 2     536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3     536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4     536365     84029E       Red Woolly Hottie White Heart.         6
#
#          Invoice_Date  Unit_Price  Customer_ID         Country
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom

# %%
df.describe()
# Out:
#             Quantity                   Invoice_Date     Unit_Price  \
# count  406829.000000                         406829  406829.000000
# mean       12.061303  2011-07-10 16:30:57.879207424       3.460471
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-31 11:48:00       1.950000
# 75%        12.000000            2011-10-20 13:06:00       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       248.693370                            NaN      69.315162
#
#          Customer_ID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df.describe().round(2)
# Out:
#         Quantity                   Invoice_Date  Unit_Price  Customer_ID
# count  406829.00                         406829   406829.00    406829.00
# mean       12.06  2011-07-10 16:30:57.879207424        3.46     15287.69
# min    -80995.00            2010-12-01 08:26:00        0.00     12346.00
# 25%         2.00            2011-04-06 15:02:00        1.25     13953.00
# 50%         5.00            2011-07-31 11:48:00        1.95     15152.00
# 75%        12.00            2011-10-20 13:06:00        3.75     16791.00
# max     80995.00            2011-12-09 12:50:00    38970.00     18287.00
# std       248.69                            NaN       69.32      1713.60

# %%
#Removing negative values from quantity column

con = df.Quantity > 0

# %%
df = df[con]

# %%
df.describe().round(2)
# Out:
#         Quantity                   Invoice_Date  Unit_Price  Customer_ID
# count  397924.00                         397924   397924.00    397924.00
# mean       13.02  2011-07-10 23:43:36.912475648        3.12     15294.32
# min         1.00            2010-12-01 08:26:00        0.00     12346.00
# 25%         2.00            2011-04-07 11:12:00        1.25     13969.00
# 50%         6.00            2011-07-31 14:39:00        1.95     15159.00
# 75%        12.00            2011-10-20 14:33:00        3.75     16795.00
# max     80995.00            2011-12-09 12:50:00     8142.75     18287.00
# std       180.42                            NaN       22.10      1713.17

# %%
df.shape
# Out:
# (397924, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397924 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Invoice_No    397924 non-null  object
#  1   Stock_Code    397924 non-null  object
#  2   Description   397924 non-null  object
#  3   Quantity      397924 non-null  int64
#  4   Invoice_Date  397924 non-null  datetime64[ns]
#  5   Unit_Price    397924 non-null  float64
#  6   Customer_ID   397924 non-null  int64
#  7   Country       397924 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 27.3+ MB

# %%
df.head()
# Out:
#   Invoice_No Stock_Code                          Description  Quantity  \
# 0     536365     85123A   White Hanging Heart T-Light Holder         6
# 1     536365      71053                  White Metal Lantern         6
# 2     536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3     536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4     536365     84029E       Red Woolly Hottie White Heart.         6
#
#          Invoice_Date  Unit_Price  Customer_ID         Country
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom

# %%
#Adding new column to know amount spend by each customer

df["Amount Spent"] = df["Unit_Price"]*df["Quantity"]
df.head()
# Out:
#   Invoice_No Stock_Code                          Description  Quantity  \
# 0     536365     85123A   White Hanging Heart T-Light Holder         6
# 1     536365      71053                  White Metal Lantern         6
# 2     536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3     536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4     536365     84029E       Red Woolly Hottie White Heart.         6
#
#          Invoice_Date  Unit_Price  Customer_ID         Country  Amount Spent
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34

# %%
for columns in df.columns:
    print(columns)
# Out:
# Invoice_No
# Stock_Code
# Description
# Quantity
# Invoice_Date
# Unit_Price
# Customer_ID
# Country
# Amount Spent

# %%
#rearranging column

column_order = ["Customer_ID","Invoice_Date","Description","Invoice_No","Unit_Price",
                "Quantity","Amount Spent","Stock_Code","Country"]

# %%
df[column_order]
# Out:
#         Customer_ID        Invoice_Date                          Description  \
# 0             17850 2010-12-01 08:26:00   White Hanging Heart T-Light Holder
# 1             17850 2010-12-01 08:26:00                  White Metal Lantern
# 2             17850 2010-12-01 08:26:00       Cream Cupid Hearts Coat Hanger
# 3             17850 2010-12-01 08:26:00  Knitted Union Flag Hot Water Bottle
# 4             17850 2010-12-01 08:26:00       Red Woolly Hottie White Heart.
# ...             ...                 ...                                  ...
# 541904        12680 2011-12-09 12:50:00          Pack Of 20 Spaceboy Napkins
# 541905        12680 2011-12-09 12:50:00         Children'S Apron Dolly Girl
# 541906        12680 2011-12-09 12:50:00        Childrens Cutlery Dolly Girl
# 541907        12680 2011-12-09 12:50:00      Childrens Cutlery Circus Parade
# 541908        12680 2011-12-09 12:50:00        Baking Set 9 Piece Retrospot
#
# ...

# %%
len(df.columns)
# Out:
# 9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397924 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Invoice_No    397924 non-null  object
#  1   Stock_Code    397924 non-null  object
#  2   Description   397924 non-null  object
#  3   Quantity      397924 non-null  int64
#  4   Invoice_Date  397924 non-null  datetime64[ns]
#  5   Unit_Price    397924 non-null  float64
#  6   Customer_ID   397924 non-null  int64
#  7   Country       397924 non-null  object
#  8   Amount Spent  397924 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 30.4+ MB

# %%
#Accessing "Invoice_Date" column

df["Invoice_Date"]
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: Invoice_Date, Length: 397924, dtype: datetime64[ns]

# %%
#Accesing year value from "Invoice_Date"

df["Invoice_Date"].dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: Invoice_Date, Length: 397924, dtype: int32

# %%
#Accesing month value from "Invoice_Date"

df["Invoice_Date"].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 541904    12
# 541905    12
# 541906    12
# 541907    12
# 541908    12
# Name: Invoice_Date, Length: 397924, dtype: int32

# %%
#Accesing day value from "Invoice_Date"

df["Invoice_Date"].dt.day_name()
# Out:
# 0         Wednesday
# 1         Wednesday
# 2         Wednesday
# 3         Wednesday
# 4         Wednesday
#             ...
# 541904       Friday
# 541905       Friday
# 541906       Friday
# 541907       Friday
# 541908       Friday
# Name: Invoice_Date, Length: 397924, dtype: object

# %%
#Accessing specific year data from "Invocie_Date"

start = df["Invoice_Date"] > "2010-01-01 00:00:00"
end = df["Invoice_Date"] < "2010-12-31 11:59:59"

result = df[start & end]
result
# Out:
#       Invoice_No Stock_Code                          Description  Quantity  \
# 0         536365     85123A   White Hanging Heart T-Light Holder         6
# 1         536365      71053                  White Metal Lantern         6
# 2         536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3         536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4         536365     84029E       Red Woolly Hottie White Heart.         6
# ...          ...        ...                                  ...       ...
# 42448     539988      84380    Set Of 3 Butterfly Cookie Cutters         1
# 42449     539988     84849D                Hot Baths Soap Holder         1
# 42450     539988     84849B               Fairy Soap Soap Holder         1
# 42451     539988      22854          Cream Sweetheart Egg Holder         2
# 42452     539988     47559B                  Tea Time Oven Glove         2
#
# ...

# %%
#Adding new column "Year" to get specific year date

df["Year"] = df["Invoice_Date"].dt.year

# %%
df.head()
# Out:
#   Invoice_No Stock_Code                          Description  Quantity  \
# 0     536365     85123A   White Hanging Heart T-Light Holder         6
# 1     536365      71053                  White Metal Lantern         6
# 2     536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3     536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4     536365     84029E       Red Woolly Hottie White Heart.         6
#
#          Invoice_Date  Unit_Price  Customer_ID         Country  Amount Spent  \
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
#
#    Year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010

# %%
#Adding new column "Month" to get specific year date

df["Month"] = df["Invoice_Date"].dt.month
df.head()
# Out:
#   Invoice_No Stock_Code                          Description  Quantity  \
# 0     536365     85123A   White Hanging Heart T-Light Holder         6
# 1     536365      71053                  White Metal Lantern         6
# 2     536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3     536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4     536365     84029E       Red Woolly Hottie White Heart.         6
#
#          Invoice_Date  Unit_Price  Customer_ID         Country  Amount Spent  \
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
#
#    Year  Month
# 0  2010     12
# 1  2010     12
# 2  2010     12
# ...

# %%
len(df.columns)
# Out:
# 11

# %%
#rearranging column

column_order = ["Customer_ID","Invoice_Date","Year","Month","Description","Invoice_No","Unit_Price",
                "Quantity","Amount Spent","Stock_Code","Country"]

# %%
df = df[column_order]

# %%
df.head()
# Out:
#    Customer_ID        Invoice_Date  Year  Month  \
# 0        17850 2010-12-01 08:26:00  2010     12
# 1        17850 2010-12-01 08:26:00  2010     12
# 2        17850 2010-12-01 08:26:00  2010     12
# 3        17850 2010-12-01 08:26:00  2010     12
# 4        17850 2010-12-01 08:26:00  2010     12
#
#                            Description Invoice_No  Unit_Price  Quantity  \
# 0   White Hanging Heart T-Light Holder     536365        2.55         6
# 1                  White Metal Lantern     536365        3.39         6
# 2       Cream Cupid Hearts Coat Hanger     536365        2.75         8
# 3  Knitted Union Flag Hot Water Bottle     536365        3.39         6
# 4       Red Woolly Hottie White Heart.     536365        3.39         6
#
#    Amount Spent Stock_Code         Country
# 0         15.30     85123A  United Kingdom
# 1         20.34      71053  United Kingdom
# 2         22.00     84406B  United Kingdom
# 3         20.34     84029G  United Kingdom
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df.groupby(by =["Country"]).count()
# Out:
#                       Customer_ID  Invoice_Date    Year   Month  Description  \
# Country
# Australia                    1185          1185    1185    1185         1185
# Austria                       398           398     398     398          398
# Bahrain                        17            17      17      17           17
# Belgium                      2031          2031    2031    2031         2031
# Brazil                         32            32      32      32           32
# Canada                        151           151     151     151          151
# Channel Islands               748           748     748     748          748
# Cyprus                        614           614     614     614          614
# Czech Republic                 25            25      25      25           25
# Denmark                       380           380     380     380          380
# EIRE                         7238          7238    7238    7238         7238
# ...

# %%
df.groupby(by = ["Country"], as_index = False)["Invoice_No"].count()
# Out:
#                  Country  Invoice_No
# 0              Australia        1185
# 1                Austria         398
# 2                Bahrain          17
# 3                Belgium        2031
# 4                 Brazil          32
# 5                 Canada         151
# 6        Channel Islands         748
# 7                 Cyprus         614
# 8         Czech Republic          25
# 9                Denmark         380
# 10                  EIRE        7238
# 11    European Community          60
# 12               Finland         685
# 13                France        8342
# 14               Germany        9042
# 15                Greece         145
# 16               Iceland         182
# 17                Israel         248
# 18                 Italy         758
# 19                 Japan         321
# 20               Lebanon          45
# 21             Lithuania          35
# 22                 Malta         112
# 23           Netherlands        2363
# ...

# %%
#Top 10 most order by "Country"
order = df.groupby(by = ["Country"], as_index = False)["Invoice_No"].count()

# %%
order.sort_values(by = "Invoice_No", ascending = False).head(10)
# Out:
#            Country  Invoice_No
# 35  United Kingdom      354345
# 14         Germany        9042
# 13          France        8342
# 10            EIRE        7238
# 30           Spain        2485
# 23     Netherlands        2363
# 3          Belgium        2031
# 32     Switzerland        1842
# 26        Portugal        1462
# 0        Australia        1185

# %%
#Top 5 most "Amount Spent" by "Country"

df_1 = df.groupby(by = "Country", as_index = False)["Amount Spent"].sum()

# %%
df_1.sort_values(by =["Amount Spent"], ascending = False).head()
# Out:
#            Country  Amount Spent
# 35  United Kingdom   7308391.554
# 23     Netherlands    285446.340
# 10            EIRE    265545.900
# 14         Germany    228867.140
# 13          France    209024.050

# %% [markdown]
# United Kingdom gives more business than any other country

# %%
#Adding new column at specific postion

new_col = df["Year"]*100 + df["Month"]
df.insert(1, "Year_Month", new_col)

# %%
# df.drop(columns ="Year_Month", inplace = True)

# %%
df.head()
# Out:
#    Customer_ID  Year_Month        Invoice_Date  Year  Month  \
# 0        17850      201012 2010-12-01 08:26:00  2010     12
# 1        17850      201012 2010-12-01 08:26:00  2010     12
# 2        17850      201012 2010-12-01 08:26:00  2010     12
# 3        17850      201012 2010-12-01 08:26:00  2010     12
# 4        17850      201012 2010-12-01 08:26:00  2010     12
#
#                            Description Invoice_No  Unit_Price  Quantity  \
# 0   White Hanging Heart T-Light Holder     536365        2.55         6
# 1                  White Metal Lantern     536365        3.39         6
# 2       Cream Cupid Hearts Coat Hanger     536365        2.75         8
# 3  Knitted Union Flag Hot Water Bottle     536365        3.39         6
# 4       Red Woolly Hottie White Heart.     536365        3.39         6
#
#    Amount Spent Stock_Code         Country
# 0         15.30     85123A  United Kingdom
# 1         20.34      71053  United Kingdom
# ...

# %%
column_order = ["Customer_ID","Year_Month","Invoice_Date","Year","Month","Description","Invoice_No","Unit_Price",
                "Quantity","Amount Spent","Stock_Code","Country"]

# %%
df = df[column_order]

# %%
df.head(2)
# Out:
#    Customer_ID  Year_Month        Invoice_Date  Year  Month  \
# 0        17850      201012 2010-12-01 08:26:00  2010     12
# 1        17850      201012 2010-12-01 08:26:00  2010     12
#
#                           Description Invoice_No  Unit_Price  Quantity  \
# 0  White Hanging Heart T-Light Holder     536365        2.55         6
# 1                 White Metal Lantern     536365        3.39         6
#
#    Amount Spent Stock_Code         Country
# 0         15.30     85123A  United Kingdom
# 1         20.34      71053  United Kingdom

# %% [markdown]
# # Data Visualization

# %%
#Top TEN customers who spend highest money

df.sort_values(by = "Amount Spent", ascending = False).head(10)
# Out:
#         Customer_ID  Year_Month        Invoice_Date  Year  Month  \
# 540421        16446      201112 2011-12-09 09:15:00  2011     12
# 61619         12346      201101 2011-01-18 10:01:00  2011      1
# 222680        15098      201106 2011-06-10 15:28:00  2011      6
# 173382        16029      201105 2011-05-03 13:46:00  2011      5
# 348325        17450      201109 2011-09-20 11:05:00  2011      9
# 160546        15749      201104 2011-04-18 13:20:00  2011      4
# 52711         15749      201101 2011-01-11 12:55:00  2011      1
# 421601        14646      201110 2011-10-27 12:11:00  2011     10
# 52709         15749      201101 2011-01-11 12:55:00  2011      1
# 160542        15749      201104 2011-04-18 13:20:00  2011      4
#
#                                 Description Invoice_No  Unit_Price  Quantity  \
# 540421          Paper Craft , Little Birdie     581483        2.08     80995
# 61619        Medium Ceramic Top Storage Jar     541431        1.04     74215
# ...

# %%
money_spend =  df.groupby(by = ["Customer_ID","Country"], as_index = False)["Amount Spent"].sum()

plt.subplots(figsize=(15,6))

plt.plot(money_spend.Customer_ID, money_spend["Amount Spent"])

plt.xlabel('Customers ID')
plt.ylabel('Money spent (Dollar)')
plt.title('Money Spent for different Customers')

plt.show()

# %%
df.head(2)
# Out:
#    Customer_ID  Year_Month        Invoice_Date  Year  Month  \
# 0        17850      201012 2010-12-01 08:26:00  2010     12
# 1        17850      201012 2010-12-01 08:26:00  2010     12
#
#                           Description Invoice_No  Unit_Price  Quantity  \
# 0  White Hanging Heart T-Light Holder     536365        2.55         6
# 1                 White Metal Lantern     536365        3.39         6
#
#    Amount Spent Stock_Code         Country
# 0         15.30     85123A  United Kingdom
# 1         20.34      71053  United Kingdom

# %%
#Most Orders by customers = "Customer_ID"

orders = df.groupby(by = ["Customer_ID","Country"], as_index = False)["Invoice_No"].count()
orders
# Out:
#       Customer_ID         Country  Invoice_No
# 0           12346  United Kingdom           1
# 1           12347         Iceland         182
# 2           12348         Finland          31
# 3           12349           Italy          73
# 4           12350          Norway          17
# ...           ...             ...         ...
# 4342        18280  United Kingdom          10
# 4343        18281  United Kingdom           7
# 4344        18282  United Kingdom          12
# 4345        18283  United Kingdom         756
# 4346        18287  United Kingdom          70
#
# [4347 rows x 3 columns]

# %%
#Top TEN most number of Orders

orders.sort_values(by = "Invoice_No", ascending = False).head(10)
# Out:
#       Customer_ID         Country  Invoice_No
# 4019        17841  United Kingdom        7847
# 1888        14911            EIRE        5677
# 1298        14096  United Kingdom        5111
# 334         12748  United Kingdom        4596
# 1670        14606  United Kingdom        2700
# 2185        15311  United Kingdom        2379
# 1698        14646     Netherlands        2080
# 570         13089  United Kingdom        1818
# 699         13263  United Kingdom        1677
# 1443        14298  United Kingdom        1637

# %%
orders = df.groupby(by = ["Customer_ID","Country"], as_index = False)["Invoice_No"].count()

plt.subplots(figsize = (15,6))

plt.plot(orders.Customer_ID, orders.Invoice_No)

plt.xlabel("Customer ID",fontsize = 15)
plt.ylabel("Number of Orders",fontsize = 15)
plt.title("Number of order by customers",fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Number of order by customers')

# %%
df.head()
# Out:
#    Customer_ID  Year_Month        Invoice_Date  Year  Month  \
# 0        17850      201012 2010-12-01 08:26:00  2010     12
# 1        17850      201012 2010-12-01 08:26:00  2010     12
# 2        17850      201012 2010-12-01 08:26:00  2010     12
# 3        17850      201012 2010-12-01 08:26:00  2010     12
# 4        17850      201012 2010-12-01 08:26:00  2010     12
#
#                            Description Invoice_No  Unit_Price  Quantity  \
# 0   White Hanging Heart T-Light Holder     536365        2.55         6
# 1                  White Metal Lantern     536365        3.39         6
# 2       Cream Cupid Hearts Coat Hanger     536365        2.75         8
# 3  Knitted Union Flag Hot Water Bottle     536365        3.39         6
# 4       Red Woolly Hottie White Heart.     536365        3.39         6
#
#    Amount Spent Stock_Code         Country
# 0         15.30     85123A  United Kingdom
# 1         20.34      71053  United Kingdom
# ...

# %%
for i in df.Year_Month.unique():
    print(i)
# Out:
# 201012
# 201101
# 201102
# 201103
# 201104
# 201105
# 201106
# 201107
# 201108
# 201109
# 201110
# 201111
# 201112

# %%
#Number of orders by each month

df.groupby(by = ["Year_Month"], as_index = False)["Invoice_No"].count()
# Out:
#     Year_Month  Invoice_No
# 0       201012       26160
# 1       201101       21232
# 2       201102       19928
# 3       201103       27177
# 4       201104       22644
# 5       201105       28322
# 6       201106       27185
# 7       201107       26827
# 8       201108       27013
# 9       201109       40030
# 10      201110       49557
# 11      201111       64545
# 12      201112       17304

# %%
color = sns.color_palette() 
#color_palette() method in seaborn library which can generate a list of colors defining a color palette

# %%
order_1 = df.groupby("Invoice_No")["Year_Month"].unique().value_counts().sort_index().plot(kind = 'bar',
                                                                    color = color[1], figsize = (13,6))

#plt.subplots(figsize = (15,0))
#plt.figure(figsize = (15,8))
# plt.plot(order_1.Invoice_No, order_1.Year_Month)


plt.xlabel("Month wise Sale", fontsize = 15)
plt.ylabel("Number of Orders", fontsize = 15)
plt.title("Order by each Month (1st Dec 2010 - 9th Dec 2011)", fontsize = 15)

t = ('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11')

ax = order_1.set_xticklabels(t, rotation = 360, fontsize = 12) #set_xticklabels() function to set custom tick labels for the x-axis

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above diagram indicates that November month having more sales

# %%
#Adding column to get weekday wise sale

df["Day"] = df["Invoice_Date"].dt.dayofweek

# %%
# df.drop(columns = "Day", inplace = True)

# %%
df.head()
# Out:
#    Customer_ID  Year_Month        Invoice_Date  Year  Month  \
# 0        17850      201012 2010-12-01 08:26:00  2010     12
# 1        17850      201012 2010-12-01 08:26:00  2010     12
# 2        17850      201012 2010-12-01 08:26:00  2010     12
# 3        17850      201012 2010-12-01 08:26:00  2010     12
# 4        17850      201012 2010-12-01 08:26:00  2010     12
#
#                            Description Invoice_No  Unit_Price  Quantity  \
# 0   White Hanging Heart T-Light Holder     536365        2.55         6
# 1                  White Metal Lantern     536365        3.39         6
# 2       Cream Cupid Hearts Coat Hanger     536365        2.75         8
# 3  Knitted Union Flag Hot Water Bottle     536365        3.39         6
# 4       Red Woolly Hottie White Heart.     536365        3.39         6
#
#    Amount Spent Stock_Code         Country  Day
# 0         15.30     85123A  United Kingdom    2
# 1         20.34      71053  United Kingdom    2
# ...

# %%
col1 = ["Customer_ID","Year_Month","Invoice_Date","Year","Month","Day","Description","Invoice_No","Unit_Price",
                "Quantity","Amount Spent","Stock_Code","Country"]

# %%
# column_order = ["Customer_ID","Year_Month","Invoice_Date","Year","Month","Description","Invoice_No","Unit_Price",
#                 "Quantity","Amount Spent","Stock_Code","Country"]

# %%
df = df[col1]

# %%
df.head()
# Out:
#    Customer_ID  Year_Month        Invoice_Date  Year  Month  Day  \
# 0        17850      201012 2010-12-01 08:26:00  2010     12    2
# 1        17850      201012 2010-12-01 08:26:00  2010     12    2
# 2        17850      201012 2010-12-01 08:26:00  2010     12    2
# 3        17850      201012 2010-12-01 08:26:00  2010     12    2
# 4        17850      201012 2010-12-01 08:26:00  2010     12    2
#
#                            Description Invoice_No  Unit_Price  Quantity  \
# 0   White Hanging Heart T-Light Holder     536365        2.55         6
# 1                  White Metal Lantern     536365        3.39         6
# 2       Cream Cupid Hearts Coat Hanger     536365        2.75         8
# 3  Knitted Union Flag Hot Water Bottle     536365        3.39         6
# 4       Red Woolly Hottie White Heart.     536365        3.39         6
#
#    Amount Spent Stock_Code         Country
# 0         15.30     85123A  United Kingdom
# 1         20.34      71053  United Kingdom
# ...

# %%
df.groupby(by = ["Invoice_No"])["Day"].unique()
# Out:
# Invoice_No
# 536365    [2]
# 536366    [2]
# 536367    [2]
# 536368    [2]
# 536369    [2]
#          ...
# 581583    [4]
# 581584    [4]
# 581585    [4]
# 581586    [4]
# 581587    [4]
# Name: Day, Length: 18536, dtype: object

# %%
df.groupby(by = ["Invoice_No"])["Day"].unique().value_counts()
# Out:
# Day
# [3]    4033
# [2]    3455
# [1]    3185
# [0]    2863
# [4]    2831
# [6]    2169
# Name: count, dtype: int64

# %%
df.groupby(by = ["Invoice_No"])["Day"].unique().value_counts().sort_index()
# Out:
# Day
# [0]    2863
# [1]    3185
# [2]    3455
# [3]    4033
# [4]    2831
# [6]    2169
# Name: count, dtype: int64

# %%
day_wise_sale = df.groupby(by = ["Invoice_No"])["Day"].unique().value_counts().sort_index().plot(
                                                    kind = "bar",color = color[0], figsize = (15,6))

day_wise_sale.set_xlabel("Day's of Week", fontsize = 15)
day_wise_sale.set_ylabel("Number of Orders", fontsize = 15)
day_wise_sale.set_title("Day Wise Order in a Week", fontsize = 15)

day = ('Mon','Tue','Wed','Thur','Fri','Sun')

ax = day_wise_sale.set_xticklabels(day, rotation = 'horizontal', fontsize = 15)

# %% [markdown]
# This diagram shows that in a week "Thursday" having more sales and no sale on "Saturday"

# %%
df.describe().Unit_Price
# Out:
# count    397924.000000
# mean          3.116174
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# std          22.096788
# Name: Unit_Price, dtype: float64

# %% [markdown]
# Unit_Price column shows that some product is having zero value.

# %%
#Filtering records for products which having ZERO price

df_free = df[df.Unit_Price == 0]
df_free["Unit_Price"].count()
# Out:
# 40

# %% [markdown]
# Total 40 records having ZERO price which means there are some free products or free products with any offer

# %%
df_free.head()
# Out:
#        Customer_ID  Year_Month        Invoice_Date  Year  Month  Day  \
# 9302         12647      201012 2010-12-05 14:02:00  2010     12    6
# 33576        16560      201012 2010-12-16 14:36:00  2010     12    3
# 40089        14911      201012 2010-12-21 13:45:00  2010     12    1
# 47068        13081      201101 2011-01-06 16:41:00  2011      1    3
# 47070        13081      201101 2011-01-06 16:41:00  2011      1    3
#
#                         Description Invoice_No  Unit_Price  Quantity  \
# 9302   Round Cake Tin Vintage Green     537197         0.0         1
# 33576  Advent Calendar Gingham Sack     539263         0.0         4
# 40089      Regency Cakestand 3 Tier     539722         0.0        10
# 47068       Paper Bunting Retrospot     540372         0.0        24
# 47070        Plasters In Tin Skulls     540372         0.0        24
#
#        Amount Spent Stock_Code         Country
# 9302            0.0      22841         Germany
# ...

# %%
df_free.Year_Month.value_counts()
# Out:
# Year_Month
# 201111    14
# 201108     6
# 201012     3
# 201101     3
# 201110     3
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201109     2
# 201102     1
# Name: count, dtype: int64

# %%
df_free.Year_Month.value_counts().sort_index()
# Out:
# Year_Month
# 201012     3
# 201101     3
# 201102     1
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201108     6
# 201109     2
# 201110     3
# 201111    14
# Name: count, dtype: int64

# %%
zero_price_by_month = df_free.Year_Month.value_counts().sort_index().plot(kind = 'bar', figsize = (14,7), color = color[2])

zero_price_by_month.set_xlabel("Month wise Distribution", fontsize = 15)
zero_price_by_month.set_ylabel("Frequency", fontsize = 15)
zero_price_by_month.set_title("Frequency for different Months (Dec 2010 - Dec 2011)", fontsize = 15)

Month = ('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11')

ax1 = zero_price_by_month.set_xticklabels(Month, rotation = 'horizontal', fontsize = 13)

# %% [markdown]
# Above Diagram shows that November month having more sale

# %%
df.head()
# Out:
#    Customer_ID  Year_Month        Invoice_Date  Year  Month  Day  \
# 0        17850      201012 2010-12-01 08:26:00  2010     12    2
# 1        17850      201012 2010-12-01 08:26:00  2010     12    2
# 2        17850      201012 2010-12-01 08:26:00  2010     12    2
# 3        17850      201012 2010-12-01 08:26:00  2010     12    2
# 4        17850      201012 2010-12-01 08:26:00  2010     12    2
#
#                            Description Invoice_No  Unit_Price  Quantity  \
# 0   White Hanging Heart T-Light Holder     536365        2.55         6
# 1                  White Metal Lantern     536365        3.39         6
# 2       Cream Cupid Hearts Coat Hanger     536365        2.75         8
# 3  Knitted Union Flag Hot Water Bottle     536365        3.39         6
# 4       Red Woolly Hottie White Heart.     536365        3.39         6
#
#    Amount Spent Stock_Code         Country
# 0         15.30     85123A  United Kingdom
# 1         20.34      71053  United Kingdom
# ...

# %%
df.shape
# Out:
# (397924, 13)

# %%
#Order by each country

df.groupby("Country")["Invoice_No"].count().sort_values()
# Out:
# Country
# Saudi Arabia                 9
# Bahrain                     17
# Czech Republic              25
# Brazil                      32
# Lithuania                   35
# Lebanon                     45
# RSA                         58
# European Community          60
# United Arab Emirates        68
# Malta                      112
# Greece                     145
# Canada                     151
# USA                        179
# Iceland                    182
# Singapore                  222
# Unspecified                244
# Israel                     248
# Japan                      321
# Poland                     330
# Denmark                    380
# Austria                    398
# Sweden                     451
# Cyprus                     614
# Finland                    685
# Channel Islands            748
# Italy                      758
# Norway                    1072
# Australia                 1185
# Portugal                  1462
# Switzerland               1842
# ...

# %%
order_by_country = df.groupby("Country")["Invoice_No"].count().sort_values()


plt.subplots(figsize=(15,8))
order_by_country.plot(kind = 'barh', fontsize=12, color=color[0])

plt.xlabel("Number of Orders", fontsize = 12)
plt.ylabel("Country Name", fontsize = 12)
plt.title("Number of Orders by each Country", fontsize = 15)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
order_by_country = df.groupby("Country")["Invoice_No"].count().sort_values()

del order_by_country["United Kingdom"]

plt.subplots(figsize=(15,8))
order_by_country.plot(kind = 'barh', fontsize=12, color=color[0])

plt.xlabel("Country Name", fontsize = 12)
plt.ylabel("Number of Orders", fontsize = 12)
plt.title("Number of Orders by each Country", fontsize = 15)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
amount_spent_by_country = df.groupby("Country")["Amount Spent"].sum().sort_values()

plt.subplots(figsize=(15,8))
amount_spent_by_country.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Money Spent (Dollar)', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.title('Money Spent by Each Countries', fontsize=15)
plt.show()

# %%
amount_spent_by_country = df.groupby("Country")["Amount Spent"].sum().sort_values()
del amount_spent_by_country["United Kingdom"]

plt.subplots(figsize=(15,8))
amount_spent_by_country.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Money Spent (Dollar)', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.title('Money Spent by Each Countries (Except "United Kingdom"))', fontsize=15)
plt.show()

# %% [markdown]
# ## Results from EDA
#
# 1. Highest number of orders from specific country
# 2. Highest money spent on purchase specific country
# 3. Top 5 countries place the highest number of orders
# 4. Top 5 countries spent the money on purchase products
# 5. Highest sales on specific Month
# 6. There are no transactions on between dates.
# 7. Sales increase days
# 8. Sales decrease days
# 9. Highest number of orders hours and etc
